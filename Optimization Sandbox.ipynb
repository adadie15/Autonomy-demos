# %% [markdown]
# <h1>Sandbox for Optimization Algorithms</h1>
#
# <h2> Goal </h2>
#
# Create a series of lightweight optimization algorithms that run on limited hardware for robotics applications. Eventually this will be converted to a C++ library for compatibility with modern robotics software. <br>
#
# Editor: Andrew Adie <br>
# Version: 0.1 <br>
# Date of Publish: 4/26/2026 <br>
